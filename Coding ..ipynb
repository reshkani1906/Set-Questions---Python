# %%
1.Write a Python program that prints numbers from 1 to 5.
Expected Output:
1 2 3 4 5

# %%
#ANSWER

# Loop through numbers 1 to 5 and print them on the same line
# Loop through numbers 1 to 5 and print them on the same line
for i in range(1, 6):
    print(i, end=" ")
# Out:
# 1 2 3 4 5

# %%
2.Write a Python program to print the first 5 even numbers. 
Expected Output:
2 4 6 8 10

# %%
#ANSWER

for i in range(2, 11, 2):
    print(i, end=" ")
# Out:
# 2 4 6 8 10

# %%
3.Write a Python program to print the sum of numbers from 1 to 10. 
Expected Output:55

# %%
#ANSWER

total_sum = sum(range(1, 11))
print(total_sum)
# Out:
# 55

# %%
4.Write a Python function to find the factorial of 5. 
Expected Output:
120

# %%
#ANSER

def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)
output = factorial(5)
print(output)
# Out:
# 120

# %%
5.Write a Python program to check if a number is prime. 
Expected Output (for input 7):
7 is a prime number

# %%
#ANSWER

def is_prime(number):
    if number <= 1:
        return False
    for i in range(2, int(number**0.5) + 1):
        if number % i == 0:
            return False 
    return True  
num = 7
if is_prime(num):
    print(f"{num} is a prime number")
else:
    print(f"{num} is not a prime number")
# Out:
# 7 is a prime number
