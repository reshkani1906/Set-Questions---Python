# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %%
#Answer

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

# %%
#Answer

a = 10
b = "5"
print(a + int(b))
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %%
#Answer

def add_numbers(a, b): #without colon ot will show error
    return a + b

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# %%
#Answer(Index Error)

numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# %%
#Answer

print("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# %%
#Answer(Cannot divide by zero)

x = 5 / 2
print(x)
# Out:
# 2.5

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# %%
#Answer

name = "Alice"
age = 25
print("Name: " + name + ", Age: " + str(age))
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
#Answer

#No error No output
#range(start, stop, step)
#the step is negative, Python expects the start value to be greater than the stop value. But 1 is already less than 10, so the range is empty.

for i in range(10,1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# %%
#Answer

#The error occurs because you used a single equals sign (=), which assigns a value, instead of a double equals sign (==), which compares two values.

x = 10
if x == 5:
    print("x is 5")

#There is no output because x is 10, so the condition 10 == 5 is False)

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# %%
#Answer

#The function definition is missing a colon (:)

def greet(name):
    print("Hello, " + name)
